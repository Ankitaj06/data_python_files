# %% [markdown]
# Variables

# %%
a = 25
b = "anki"
c = 2.9
is_pass = True

print(a,b,c,is_pass)
print(type(c))


float_to_int = int(c)
print(float_to_int)

type(float_to_int)
# Out:
# 25 anki 2.9 True
# <class 'float'>
# 2
# int

# %% [markdown]
# List
# -mutable
# -heterogeneous
# -ordered

# %%
name = ["ankita","afsana","teju","zakera","anchal","neha"]

print(name)

print(name[0])
print(name[-1])
print(name[0:3])
print(name[1:2])

len(name)

num = [60,20,30,40,50]
print(num)
len(num)
print(min(num))
print(max(num))
print(sum(num))
sorted(num)

tuple1 = (2,3,4,1)
print(tuple1)
#tuple to list
newlist = list(tuple1)
print(newlist)

print(list(enumerate(name)))

mixed_list = ["anki",20,90.1,True,False,"hello"]
print(mixed_list)

#adding item
name.append("asmita")
print(name)

name.remove("neha")
print(name)

"asmita" in name
"neha" in name

name.pop(0)
print(name)

name.insert(2,"priti")
print(name)

name.extend(["teja","adnan","anmol"])
print(name)

newlist.sort()
print(newlist)

a = [2,5,6,1,2,4]
print(sorted(a))
a.sort()
print(a)
# Out:
# ['ankita', 'afsana', 'teju', 'zakera', 'anchal', 'neha']
# ankita
# neha
# ['ankita', 'afsana', 'teju']
# ['afsana']
# [60, 20, 30, 40, 50]
# 20
# 60
# 200
# (2, 3, 4, 1)
# [2, 3, 4, 1]
# [(0, 'ankita'), (1, 'afsana'), (2, 'teju'), (3, 'zakera'), (4, 'anchal'), (5, 'neha')]
# ['anki', 20, 90.1, True, False, 'hello']
# ['ankita', 'afsana', 'teju', 'zakera', 'anchal', 'neha', 'asmita']
# ['ankita', 'afsana', 'teju', 'zakera', 'anchal', 'asmita']
# ['afsana', 'teju', 'zakera', 'anchal', 'asmita']
# ['afsana', 'teju', 'priti', 'zakera', 'anchal', 'asmita']
# ['afsana', 'teju', 'priti', 'zakera', 'anchal', 'asmita', 'teja', 'adnan', 'anmol']
# [1, 2, 3, 4]
# [1, 2, 2, 4, 5, 6]
# [1, 2, 2, 4, 5, 6]

# %% [markdown]
# tuples

# %%
tuple1 = (1,2,3,2,2,1,"anki",True)
print(tuple1)

print(len(tuple1))
print(tuple1[0])
print(tuple1[-1])
print(tuple1[1:-1])

print(tuple1.count(2))
#int1, str1, bool1 = tuple1
#print(int1)
#print(bool1)

print(tuple1.index("anki"))
# Out:
# (1, 2, 3, 2, 2, 1, 'anki', True)
# 8
# 1
# True
# (2, 3, 2, 2, 1, 'anki')
# 3
# 6
