# %%
print("this is my first git file to push in my github")
print("Author : Ankita Jaiswal")
print("git is one of the tool where we can track history of code")

skills = ['python', 'power bi', 'data visualization', 'data Cleaning', 'sql' , 'machine learning', 'git', 'github']

for skill in skills:
    print(skill)
# Out:
# this is my first git file to push in my github
# Author : Ankita Jaiswal
# git is one of the tool where we can track history of code
# python
# power bi
# data visualization
# data Cleaning
# sql
# machine learning
# git
# github

# %%
pwd
# Out:
# 'C:\\Users\\anike'

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\anike
